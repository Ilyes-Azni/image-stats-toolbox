# %%
import sys
import os

# Add the project root directory to the Python path
# Adjust the path as needed to point to your project root
sys.path.append(os.path.abspath('..'))  # If notebook is one level below project root
# or
sys.path.append(os.path.abspath('../..'))  # If notebook is two levels below project root
# or specify the full path
# sys.path.append('/path/to/image-stats-toolbox')

# %%
import src.utils.image_loader as il

# %%
data = il.ImageLoader(r"C:\Users\PC\Desktop\données\deepfake_database\train")

# %%
import src.utils.visualisation as vis

# %%
data.get_class_names()

viz = vis.DatasetVisualizer()

# %%
viz.viz(data)

# %%
import src.outliers.mahalanobis as mh

# %%
mh.mahalanobis(data, class_name="df")
